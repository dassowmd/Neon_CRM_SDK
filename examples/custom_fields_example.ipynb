# %% [markdown]
# # Custom Fields Examples
#
# This notebook demonstrates comprehensive custom field operations with the Neon CRM SDK, including:
#
# - Finding custom fields by name and ID
# - Searching accounts by custom field values
# - Including custom field values in search results
# - Best practices for custom field operations
# - Migration analysis for existing custom fields
#
# ## What Are Custom Fields?
#
# Custom fields allow organizations to extend their CRM with additional data fields specific to their needs. Common examples include:
# - Volunteer interests and skills
# - Industry classifications for companies
# - Membership levels and preferences
# - Communication preferences
# - Legacy system IDs
#
# ## Prerequisites
#
# Before running this notebook, make sure you have:
# 1. Installed the Neon CRM SDK: `pip install neon-crm`
# 2. Set up your environment variables:
#    - `NEON_ORG_ID`: Your organization ID
#    - `NEON_API_KEY`: Your API key
# 3. Or update the client initialization below with your credentials

# %% [markdown]
# ## Import Required Libraries

# %%
import os
from typing import Dict, Optional

from neon_crm import NeonClient

# %% [markdown]
# ## Initialize the Neon CRM Client

# %%
# Initialize the client with environment variables or direct credentials
client = NeonClient(
    org_id=os.getenv("NEON_ORG_ID"),
    api_key=os.getenv("NEON_API_KEY"),
    environment="production",  # or "trial"
)

# Alternative: Set credentials directly (not recommended for production)
# client = NeonClient(
#     org_id="your_org_id_here",
#     api_key="your_api_key_here",
#     environment="production"
# )

print("🎯 Neon CRM client initialized for custom fields examples!")
# Out:
# 🎯 Neon CRM client initialized for custom fields examples!

# %% [markdown]
# ## Example 1: List All Custom Fields
#
# Start by exploring what custom fields are available in your organization.

# %%
def list_all_custom_fields():
    """List all custom fields for accounts."""
    print("📋 Available Custom Fields for Accounts:")
    print("=" * 50)

    try:
        custom_fields = list(client.accounts.list_custom_fields())

        if not custom_fields:
            print("ℹ️  No custom fields found for accounts")
            print("   This might mean:")
            print("   • Your organization hasn't set up custom fields yet")
            print("   • You don't have permission to view custom fields")
            print("   • The fields are configured differently")
            return []

        # Show first 10 fields with details
        print(f"Found {len(custom_fields)} custom fields. Showing details:")
        print()

        for i, field in enumerate(custom_fields[:10], 1):
            field_id = field.get("id")
            field_name = field.get("name", "Unknown")
            field_type = field.get("fieldType", "Unknown")

            print(
                f"{i:2}. ID: {field_id:3} | Type: {field_type:15} | Name: '{field_name}'"
            )

        if len(custom_fields) > 10:
            print(f"\n... and {len(custom_fields) - 10} more fields")

        print(f"\n✅ Found {len(custom_fields)} total custom fields")
        return custom_fields

    except Exception as e:
        print(f"❌ Error listing custom fields: {e}")
        return []


# Run the example
custom_fields = list_all_custom_fields()
# Out:
# 📋 Available Custom Fields for Accounts:
# ==================================================
# Found 51 custom fields. Showing details:
#
#  1. ID: 111 | Type: Unknown         | Name: 'DPW ID'
#  2. ID: 144 | Type: Unknown         | Name: 'If bringing, indicate the dish you will share.'
#  3. ID: 101 | Type: Unknown         | Name: 'Occupation'
#  4. ID: 113 | Type: Unknown         | Name: 'V-Annual Fundraising Event Committee'
#  5. ID: 86  | Type: Unknown         | Name: 'V-Canvassing'
#  6. ID: 119 | Type: Unknown         | Name: 'V-Coffee Klatch Interest'
#  7. ID: 78  | Type: Unknown         | Name: 'V-Communications Team - website, newsletter, blog, messaging, graphic design'
#  8. ID: 87  | Type: Unknown         | Name: 'V-Data Entry '
#  9. ID: 77  | Type: Unknown         | Name: 'V-Date Contacted'
# 10. ID: 108 | Type: Unknown         | Name: 'V-Diversity Outreach Team'
#
# ... and 41 more fields
#
# ✅ Found 51 total custom fields
# Found 51 custom fields. Showing details:
#
#  1. ID: 111 | Type: Unknown         | Name: 'DPW ID'
#  2. ID: 144 | Type: Unknown         | Name: 'If bringing, indicate the dish you will share.'
#  3. ID: 101 | Type: Unknown         | Name: 'Occupation'
#  4. ID: 113 | Type: Unknown         | Name: 'V-Annual Fundraising Event Committee'
#  5. ID: 86  | Type: Unknown         | Name: 'V-Canvassing'
#  6. ID: 119 | Type: Unknown         | Name: 'V-Coffee Klatch Interest'
#  7. ID: 78  | Type: Unknown         | Name: 'V-Communications Team - website, newsletter, blog, messaging, graphic design'
#  8. ID: 87  | Type: Unknown         | Name: 'V-Data Entry '
#  9. ID: 77  | Type: Unknown         | Name: 'V-Date Contacted'
# 10. ID: 108 | Type: Unknown         | Name: 'V-Diversity Outreach Team'
#
# ... and 41 more fields
#
# ✅ Found 51 total custom fields

# %% [markdown]
# ## Example 2: Find Custom Field by Name
#
# When you know the name of a custom field, you can find it efficiently.

# %%
def find_custom_field_by_name(field_name: str) -> Optional[Dict]:
    """Find a custom field by its name."""
    print(f"🔍 Looking for custom field: '{field_name}'")

    try:
        field = client.accounts.find_custom_field_by_name(field_name)

        if field:
            field_id = field.get("id")
            field_type = field.get("fieldType")
            options = field.get("options", [])

            print("✅ Found field:")
            print(f"   ID: {field_id}")
            print(f"   Type: {field_type}")
            print(f"   Name: '{field_name}'")

            if options:
                print(
                    f"   Options: {', '.join(options[:5])}{'...' if len(options) > 5 else ''}"
                )

            return field
        else:
            print(f"❌ Custom field '{field_name}' not found")
            print("   💡 Tips:")
            print("      • Check spelling and capitalization")
            print("      • Use the exact field name from the list above")
            print("      • Some fields might be case-sensitive")
            return None

    except Exception as e:
        print(f"❌ Error finding custom field: {e}")
        return None


# Example: Find a custom field by name
print("\n🔍 Find Custom Field by Name")
print("=" * 35)

# If we have custom fields, try to find the first one
if custom_fields:
    example_field_name = custom_fields[0].get("name", "Unknown")
    print(f"Searching for the first field: '{example_field_name}'")
    found_field = find_custom_field_by_name(example_field_name)
else:
    print("⚠️  No custom fields available to search for")
    found_field = None
# Out:
# 🔍 Find Custom Field by Name
# ===================================
# Searching for the first field: 'DPW ID'
# 🔍 Looking for custom field: 'DPW ID'
# ✅ Found field:
#    ID: 111
#    Type: None
#    Name: 'DPW ID'
# ✅ Found field:
#    ID: 111
#    Type: None
#    Name: 'DPW ID'

# %% [markdown]
# ## Example 3: Search Accounts by Custom Field Values
#
# One of the most powerful features is searching for accounts based on their custom field values.

# %%
def search_by_custom_field(field_id: int, field_name: str):
    """Search for accounts with non-blank values in a custom field."""
    print(f"🔍 Searching accounts with non-blank '{field_name}' (ID: {field_id})")

    try:
        search_request = {
            "searchFields": [
                {"field": field_id, "operator": "NOT_BLANK"}  # Use integer field ID
            ],
            "outputFields": [
                "Account ID",
                "First Name",
                "Last Name",
                "Email 1",
                int(field_id),  # Include custom field in output (integer ID)
            ],
            "pagination": {"currentPage": 0, "pageSize": 200},  # Limit results for demo
        }

        results = list(client.accounts.search(search_request))

        print(f"✅ Found {len(results)} accounts with non-blank values")

        if results:
            print("\nSample results:")
            # Show sample results
            for i, account in enumerate(results[:5], 1):
                account_id = account.get("Account ID")
                first_name = account.get("First Name", "")
                last_name = account.get("Last Name", "")
                email = account.get("Email 1", "No email")

                # Custom field values are returned with display name as key
                custom_value = account.get(field_name, "N/A")

                name = f"{first_name} {last_name}".strip()
                print(f"  {i}. Account {account_id}: {name}")
                print(f"     Email: {email}")
                print(f"     {field_name}: '{custom_value}'")
                print()

            if len(results) > 5:
                print(f"    ... and {len(results) - 5} more accounts")
        else:
            print("   No accounts found with non-blank values in this field")

        return results

    except Exception as e:
        print(f"❌ Error searching by custom field: {e}")
        return []


# Run the search example if we have a custom field
print("\n🎯 Search by Custom Field Values")
print("=" * 35)

if found_field:
    field_id = found_field.get("id")
    field_name = found_field.get("name")
    search_results = search_by_custom_field(field_id, field_name)
else:
    print("⚠️  No custom field available for search example")
    search_results = []
# Out:
# 🎯 Search by Custom Field Values
# ===================================
# 🔍 Searching accounts with non-blank 'DPW ID' (ID: 111)
# ✅ Found 0 accounts with non-blank values
#    No accounts found with non-blank values in this field

# %% [markdown]
# ## Example 4: Search by Specific Custom Field Value
#
# Sometimes you want to find accounts with specific values in custom fields.

# %%
def search_by_custom_field_value(field_id: int, field_name: str, search_value: str):
    """Search for accounts with specific custom field values."""
    print(f"🔍 Searching accounts where '{field_name}' contains '{search_value}'")

    try:
        search_request = {
            "searchFields": [
                {"field": field_id, "operator": "CONTAIN", "value": search_value}
            ],
            "outputFields": [
                "Account ID",
                "First Name",
                "Last Name",
                "Email 1",
                int(field_id),  # Include the custom field value
            ],
            "pagination": {"currentPage": 0, "pageSize": 200},
        }

        results = list(client.accounts.search(search_request))

        print(f"✅ Found {len(results)} accounts matching '{search_value}'")

        if results:
            print("\nMatching accounts:")
            for i, account in enumerate(results, 1):
                account_id = account.get("Account ID")
                first_name = account.get("First Name", "")
                last_name = account.get("Last Name", "")
                email = account.get("Email 1", "No email")
                custom_value = account.get(field_name, "N/A")

                name = f"{first_name} {last_name}".strip()
                print(f"  {i}. Account {account_id}: {name}")
                print(f"     Email: {email}")
                print(f"     {field_name}: '{custom_value}'")
                print()
        else:
            print(f"   No accounts found with '{search_value}' in {field_name}")

        return results

    except Exception as e:
        print(f"❌ Error searching by custom field value: {e}")
        return []


# Example: Search for specific value
print("\n🎯 Search by Specific Value")
print("=" * 30)

if found_field:
    field_id = found_field.get("id")
    field_name = found_field.get("name")

    # Common search terms - you can modify these
    search_terms = ["volunteer", "member", "yes", "active", "interested"]

    print(f"Trying common search terms in '{field_name}':")
    for term in search_terms[:2]:  # Try first 2 terms
        print(f"\n🔎 Searching for '{term}':")
        results = search_by_custom_field_value(field_id, field_name, term)
        if results:
            break  # Stop after finding matches
else:
    print("⚠️  No custom field available for value search example")
# Out:
# 🎯 Search by Specific Value
# ==============================
# Trying common search terms in 'DPW ID':
#
# 🔎 Searching for 'volunteer':
# 🔍 Searching accounts where 'DPW ID' contains 'volunteer'
# ✅ Found 0 accounts matching 'volunteer'
#    No accounts found with 'volunteer' in DPW ID
#
# 🔎 Searching for 'member':
# 🔍 Searching accounts where 'DPW ID' contains 'member'
# ✅ Found 0 accounts matching 'member'
#    No accounts found with 'member' in DPW ID

# %% [markdown]
# ## Example 5: Multiple Custom Fields Search
#
# Search using multiple custom fields at once to find accounts with specific combinations of data.

# %%
def search_multiple_custom_fields(field_mapping: Dict[str, int]):
    """Search by multiple custom fields and include all in output."""
    print("🔍 Searching by multiple custom fields")
    print(f"Fields: {list(field_mapping.keys())}")

    # Build search fields for all custom fields
    search_fields = []
    output_fields = ["Account ID", "First Name", "Last Name", "Email 1"]

    for _field_name, field_id in field_mapping.items():
        search_fields.append({"field": field_id, "operator": "NOT_BLANK"})
        output_fields.append(int(field_id))  # Add to output

    try:
        search_request = {
            "searchFields": search_fields,
            "outputFields": output_fields,
            "pagination": {"currentPage": 0, "pageSize": 200},
        }

        results = list(client.accounts.search(search_request))

        print(
            f"✅ Found {len(results)} accounts with all specified custom fields populated"
        )

        if results:
            print("\nAccounts with all fields populated:")
            for i, account in enumerate(results, 1):
                account_id = account.get("Account ID")
                first_name = account.get("First Name", "")
                last_name = account.get("Last Name", "")
                email = account.get("Email 1", "No email")

                name = f"{first_name} {last_name}".strip()
                print(f"  {i}. Account {account_id}: {name}")
                print(f"     Email: {email}")

                # Show all custom field values
                for field_name in field_mapping.keys():
                    custom_value = account.get(field_name, "N/A")
                    print(f"     {field_name}: '{custom_value}'")
                print()
        else:
            print("   No accounts found with all specified fields populated")

        return results

    except Exception as e:
        print(f"❌ Error in multi-field search: {e}")
        return []


# Example: Multiple fields search
print("\n🎯 Multiple Custom Fields Search")
print("=" * 35)

if len(custom_fields) >= 2:
    # Use first 2 custom fields for the example
    field_mapping = {
        custom_fields[0]["name"]: custom_fields[0]["id"],
        custom_fields[1]["name"]: custom_fields[1]["id"],
    }
    multi_results = search_multiple_custom_fields(field_mapping)
else:
    print("⚠️  Need at least 2 custom fields for multi-field search example")
    if custom_fields:
        print(f"   Only {len(custom_fields)} custom field(s) available")
# Out:
# 🎯 Multiple Custom Fields Search
# ===================================
# 🔍 Searching by multiple custom fields
# Fields: ['DPW ID', 'If bringing, indicate the dish you will share.']
# ✅ Found 0 accounts with all specified custom fields populated
#    No accounts found with all specified fields populated

# %% [markdown]
# ## Example 6: Custom Field Migration Analysis
#
# This example shows how to analyze custom fields for data migration or cleanup purposes.

# %%
def custom_field_migration_example():
    """Example of analyzing custom fields for migration (like V-fields)."""
    print("📊 Custom Field Migration Analysis Example")
    print("=" * 50)

    # Example target fields - these might be from a legacy system
    # You can modify these to match your actual field names
    target_fields = [
        "V-Annual Fundraising Event Committee",
        "V-Canvassing",
        "V-Coffee Klatch Interest",
        "V-Communications Team - website, newsletter, blog, messaging, graphic design",
        "V-Data Entry",
    ]

    # If we don't have these specific fields, use the first few available fields
    if not any(field.get("name") in target_fields for field in custom_fields):
        print("ℹ️  Example V-fields not found. Using available fields for demo:")
        target_fields = [field.get("name") for field in custom_fields[:5]]
        if not target_fields:
            print("❌ No custom fields available for migration analysis")
            return

    results_summary = {}

    for field_name in target_fields:
        print(f"\n🔍 Analyzing: {field_name}")

        # Find the field
        field = client.accounts.find_custom_field_by_name(field_name)
        if not field:
            print("  ❌ Field not found")
            results_summary[field_name] = {"status": "not_found"}
            continue

        field_id = field["id"]
        field_type = field.get("fieldType", "Unknown")
        print(f"  ✅ Found - ID: {field_id}, Type: {field_type}")

        try:
            # Count accounts with non-blank values
            search_request = {
                "searchFields": [{"field": field_id, "operator": "NOT_BLANK"}],
                "outputFields": ["Account ID"],
                "pagination": {"currentPage": 0, "pageSize": 100},  # Get more to count
            }

            # Get results to count them
            results = list(client.accounts.search(search_request))
            count = len(results)

            print(f"  📊 {count} accounts have non-blank values")

            # Get a sample of values if any exist
            if count > 0 and results:
                sample_search = {
                    "searchFields": [{"field": field_id, "operator": "NOT_BLANK"}],
                    "outputFields": ["Account ID", field_id],
                    "pagination": {"currentPage": 0, "pageSize": 200},
                }
                sample_results = list(client.accounts.search(sample_search))

                if sample_results:
                    print("  📝 Sample values:")
                    for result in sample_results:
                        value = result.get(field_name, "N/A")
                        account_id = result.get("Account ID")
                        print(f"     Account {account_id}: '{value}'")

            results_summary[field_name] = {
                "status": "found",
                "field_id": field_id,
                "field_type": field_type,
                "count": count,
            }

        except Exception as e:
            print(f"  ❌ Error analyzing field: {e}")
            results_summary[field_name] = {
                "status": "error",
                "field_id": field_id,
                "error": str(e),
            }

    # Print summary
    print("\n📊 MIGRATION ANALYSIS SUMMARY")
    print("=" * 35)

    total_records = sum(
        data.get("count", 0)
        for data in results_summary.values()
        if data.get("status") == "found"
    )

    found_fields = 0
    fields_with_data = 0

    for field_name, data in results_summary.items():
        status = data.get("status")

        if status == "not_found":
            print(f"❌ {field_name}: Field not found")
        elif status == "error":
            print(f"⚠️  {field_name}: Error occurred")
        elif status == "found":
            found_fields += 1
            count = data.get("count", 0)
            if count == 0:
                print(f"⭕ {field_name}: No data (0 records)")
            else:
                fields_with_data += 1
                print(f"✅ {field_name}: {count} records")

    print("\n🎯 Analysis Results:")
    print(f"   Total fields analyzed: {len(target_fields)}")
    print(f"   Fields found: {found_fields}")
    print(f"   Fields with data: {fields_with_data}")
    print(f"   Total records across all fields: {total_records}")

    if fields_with_data > 0:
        print("\n💡 Migration Recommendations:")
        print(
            f"   • {fields_with_data} fields contain data and should be included in migration"
        )
        print("   • Consider data validation and cleanup for fields with many records")
        print("   • Test migration process with a subset of accounts first")


# Run the migration analysis
print("\n📊 Custom Field Migration Analysis")
print("=" * 40)
custom_field_migration_example()
# Out:
# 📊 Custom Field Migration Analysis
# ========================================
# 📊 Custom Field Migration Analysis Example
# ==================================================
#
# 🔍 Analyzing: V-Annual Fundraising Event Committee
#   ✅ Found - ID: 113, Type: Unknown
#   📊 52 accounts have non-blank values
#   📝 Sample values:
#      Account 4828: 'Yes'
#      Account 4833: 'Yes'
#      Account 5217: 'Yes'
#      Account 2045: 'Yes'
#      Account 4912: 'Yes'
#      Account 5247: 'Yes'
#      Account 5473: 'Yes'
#      Account 1609: 'Yes'
#      Account 1258: 'Yes'
#      Account 4965: 'Yes'
#      Account 6532: 'Yes'
#      Account 5480: 'Yes'
#      Account 2131: 'Yes'
#      Account 979: 'Yes'
#      Account 2087: 'Yes'
#      Account 1473: 'Yes'
#      Account 5681: 'Yes'
#      Account 5023: 'Yes'
#      Account 1106: 'Yes'
#      Account 5680: 'Yes'
#      Account 6724: 'Yes'
#      Account 1639: 'Yes'
#      Account 4707: 'Yes'
#      Account 4700: 'Yes'
#      Account 4905: 'Yes'
#      Account 3862: 'Yes'
#      Account 2043: 'Yes'
#      Account 5440: 'Yes'
#      Account 1397: 'Yes'
#      Account 1534: 'Yes'
#      Account 5505: 'Yes'
#      Account 5925: 'Yes'
#      Account 6224: 'Yes'
#      Account 6222: 'Yes'
#      Account 5724: 'Yes'
#      Account 6021: 'Yes'
#      Account 6488: 'Yes'
#      Account 4859: 'Yes'
#      Account 2090: 'Yes'
#      Account 1386: 'Yes'
#      Account 1127: 'Yes'
#      Account 6041: 'Yes'
#      Account 4884: 'Yes'
#      Account 6627: 'Yes'
#      Account 3798: 'Yes'
#      Account 4892: 'Yes'
#      Account 1231: 'Yes'
#      Account 1136: 'Yes'
#      Account 1803: 'Yes'
#      Account 6655: 'Yes'
#      Account 5601: 'Yes'
#      Account 3796: 'Yes'
#
# 🔍 Analyzing: V-Canvassing
#   ✅ Found - ID: 86, Type: Unknown
#   📊 218 accounts have non-blank values
#   📝 Sample values:
#      Account 5602: 'Yes'
#      Account 4781: 'Yes'
#      Account 4828: 'Yes'
#      Account 5172: 'Yes'
#      Account 1225: 'Yes'
#      Account 1649: 'Yes'
#      Account 1854: 'Yes'
#      Account 5217: 'Yes'
#      Account 6852: 'Yes'
#      Account 6398: 'Yes'
#      Account 5611: 'Yes'
#      Account 5670: 'Yes'
#      Account 6315: 'Yes'
#      Account 5087: 'Yes'
#      Account 1829: 'Yes'
#      Account 1578: 'Yes'
#      Account 4834: 'Yes'
#      Account 1146: 'Yes'
#      Account 4912: 'Yes'
#      Account 4875: 'Yes'
#      Account 5247: 'Yes'
#      Account 1453: 'Yes'
#      Account 1609: 'Yes'
#      Account 1961: 'Yes'
#      Account 1726: 'Yes'
#      Account 5967: 'Yes'
#      Account 4965: 'Yes'
#      Account 1381: 'Yes'
#      Account 5248: 'Yes'
#      Account 1657: 'Yes'
#      Account 6532: 'Yes'
#      Account 2291: 'Yes'
#      Account 1290: 'Yes'
#      Account 2087: 'Yes'
#      Account 1473: 'Yes'
#      Account 5457: 'Yes'
#      Account 2108: 'Yes'
#      Account 1423: 'Yes'
#      Account 5681: 'Yes'
#      Account 4757: 'Yes'
#      Account 1253: 'Yes'
#      Account 3852: 'Yes'
#      Account 5792: 'Yes'
#      Account 5768: 'Yes'
#      Account 904: 'Yes'
#      Account 6625: 'Yes'
#      Account 1793: 'Yes'
#      Account 4726: 'Yes'
#      Account 6287: 'Yes'
#      Account 2298: 'Yes'
#      Account 5870: 'Yes'
#      Account 1527: 'Yes'
#      Account 4665: 'Yes'
#      Account 1715: 'Yes'
#      Account 5617: 'Yes'
#      Account 5413: 'Yes'
#      Account 2079: 'Yes'
#      Account 5596: 'Yes'
#      Account 5680: 'Yes'
#      Account 6724: 'Yes'
#      Account 5735: 'Yes'
#      Account 5969: 'Yes'
#      Account 4700: 'Yes'
#      Account 4905: 'Yes'
#      Account 5487: 'Yes'
#      Account 5441: 'Yes'
#      Account 3194: 'Yes'
#      Account 2362: 'Yes'
#      Account 5491: 'Yes'
#      Account 3862: 'Yes'
#      Account 971: 'Yes'
#      Account 5189: 'Yes'
#      Account 1553: 'Yes'
#      Account 1565: 'Yes'
#      Account 959: 'Yes'
#      Account 2043: 'Yes'
#      Account 5927: 'Yes'
#      Account 2299: 'Yes'
#      Account 1838: 'Yes'
#      Account 1165: 'Yes'
#      Account 1018: 'Yes'
#      Account 2112: 'Yes'
#      Account 1352: 'Yes'
#      Account 4754: 'Yes'
#      Account 5173: 'Yes'
#      Account 6320: 'Yes'
#      Account 5616: 'Yes'
#      Account 3217: 'Yes'
#      Account 2371: 'Yes'
#      Account 1749: 'Yes'
#      Account 1766: 'Yes'
#      Account 4782: 'Yes'
#      Account 1320: 'Yes'
#      Account 885: 'Yes'
#      Account 5883: 'Yes'
#      Account 5505: 'Yes'
#      Account 4845: 'Yes'
#      Account 5925: 'Yes'
#      Account 4751: 'Yes'
#      Account 6355: 'Yes'
#      Account 1631: 'Yes'
#      Account 5926: 'Yes'
#      Account 2044: 'Yes'
#      Account 1794: 'Yes'
#      Account 1375: 'Yes'
#      Account 5973: 'Yes'
#      Account 2300: 'Yes'
#      Account 1246: 'Yes'
#      Account 2306: 'Yes'
#      Account 5648: 'Yes'
#      Account 1567: 'Yes'
#      Account 1156: 'Yes'
#      Account 889: 'Yes'
#      Account 5980: 'Yes'
#      Account 5180: 'Yes'
#      Account 6649: 'Yes'
#      Account 5978: 'Yes'
#      Account 1390: 'Yes'
#      Account 5932: 'Yes'
#      Account 6019: 'Yes'
#      Account 1377: 'Yes'
#      Account 5613: 'Yes'
#      Account 2297: 'Yes'
#      Account 5485: 'Yes'
#      Account 2289: 'Yes'
#      Account 2295: 'Yes'
#      Account 1354: 'Yes'
#      Account 6021: 'Yes'
#      Account 5193: 'Yes'
#      Account 1188: 'Yes'
#      Account 1901: 'Yes'
#      Account 5928: 'Yes'
#      Account 5731: 'Yes'
#      Account 5659: 'Yes'
#      Account 1899: 'Yes'
#      Account 2296: 'Yes'
#      Account 6066: 'Yes'
#      Account 4859: 'Yes'
#      Account 5213: 'Yes'
#      Account 5959: 'Yes'
#      Account 4773: 'Yes'
#      Account 2281: 'Yes'
#      Account 3875: 'Yes'
#      Account 1386: 'Yes'
#      Account 5466: 'Yes'
#      Account 877: 'Yes'
#      Account 2078: 'Yes'
#      Account 6011: 'Yes'
#      Account 6041: 'Yes'
#      Account 1463: 'Yes'
#      Account 5361: 'Yes'
#      Account 2290: 'Yes'
#      Account 1206: 'Yes'
#      Account 5499: 'Yes'
#      Account 6367: 'Yes'
#      Account 5946: 'Yes'
#      Account 4780: 'Yes'
#      Account 2292: 'Yes'
#      Account 4818: 'Yes'
#      Account 1963: 'Yes'
#      Account 4719: 'Yes'
#      Account 3687: 'Yes'
#      Account 1646: 'Yes'
#      Account 1465: 'Yes'
#      Account 6477: 'Yes'
#      Account 1455: 'Yes'
#      Account 882: 'Yes'
#      Account 5574: 'Yes'
#      Account 5787: 'Yes'
#      Account 6443: 'Yes'
#      Account 1962: 'Yes'
#      Account 6627: 'Yes'
#      Account 3798: 'Yes'
#      Account 900: 'Yes'
#      Account 994: 'Yes'
#      Account 1247: 'Yes'
#      Account 4892: 'Yes'
#      Account 4791: 'Yes'
#      Account 1231: 'Yes'
#      Account 2111: 'Yes'
#      Account 1787: 'Yes'
#      Account 6026: 'Yes'
#      Account 917: 'Yes'
#      Account 5854: 'Yes'
#      Account 2442: 'Yes'
#      Account 5444: 'Yes'
#      Account 4779: 'Yes'
#      Account 1137: 'Yes'
#      Account 4746: 'Yes'
#      Account 5836: 'Yes'
#      Account 5435: 'Yes'
#      Account 1753: 'Yes'
#      Account 1136: 'Yes'
#      Account 5433: 'Yes'
#      Account 3573: 'Yes'
#      Account 3858: 'Yes'
#      Account 5796: 'Yes'
#      Account 5697: 'Yes'
#      Account 1345: 'Yes'
#      Account 5637: 'Yes'
#      Account 2293: 'Yes'
#      Account 1144: 'Yes'
#      Account 1908: 'Yes'
#      Account 6194: 'Yes'
#      Account 4755: 'Yes'
#      Account 4750: 'Yes'
#      Account 1959: 'Yes'
#      Account 5398: 'Yes'
#      Account 5464: 'Yes'
#      Account 2258: 'Yes'
#      Account 5757: 'Yes'
#      Account 5559: 'Yes'
#      Account 1020: 'Yes'
#      Account 1105: 'Yes'
#      Account 4844: 'Yes'
#      Account 1129: 'Yes'
#      Account 4758: 'Yes'
#      Account 1001: 'Yes'
#
# 🔍 Analyzing: V-Coffee Klatch Interest
#   ✅ Found - ID: 119, Type: Unknown
#   📊 113 accounts have non-blank values
#   📝 Sample values:
#      Account 5172: 'Yes'
#      Account 1225: 'Yes'
#      Account 2257: 'Yes'
#      Account 1649: 'Yes'
#      Account 1576: 'Yes'
#      Account 5611: 'Yes'
#      Account 1416: 'Yes'
#      Account 1647: 'Yes'
#      Account 1421: 'Yes'
#      Account 5501: 'Yes'
#      Account 1198: 'Yes'
#      Account 1822: 'Yes'
#      Account 977: 'Yes'
#      Account 979: 'Yes'
#      Account 1404: 'Yes'
#      Account 5681: 'Yes'
#      Account 1752: 'Yes'
#      Account 5768: 'Yes'
#      Account 989: 'Yes'
#      Account 1202: 'Yes'
#      Account 1801: 'Yes'
#      Account 1760: 'Yes'
#      Account 1648: 'Yes'
#      Account 1322: 'Yes'
#      Account 5680: 'Yes'
#      Account 6724: 'Yes'
#      Account 1116: 'Yes'
#      Account 1218: 'Yes'
#      Account 1003: 'Yes'
#      Account 1291: 'Yes'
#      Account 3194: 'Yes'
#      Account 963: 'Yes'
#      Account 1124: 'Yes'
#      Account 932: 'Yes'
#      Account 3862: 'Yes'
#      Account 6198: 'Yes'
#      Account 1244: 'Yes'
#      Account 1849: 'Yes'
#      Account 1850: 'Yes'
#      Account 959: 'Yes'
#      Account 990: 'Yes'
#      Account 1018: 'Yes'
#      Account 949: 'Yes'
#      Account 1410: 'Yes'
#      Account 1749: 'Yes'
#      Account 908: 'Yes'
#      Account 1596: 'Yes'
#      Account 1630: 'Yes'
#      Account 1089: 'Yes'
#      Account 1175: 'Yes'
#      Account 5505: 'Yes'
#      Account 1823: 'Yes'
#      Account 1470: 'Yes'
#      Account 1551: 'Yes'
#      Account 5585: 'Yes'
#      Account 6224: 'Yes'
#      Account 1521: 'Yes'
#      Account 1810: 'Yes'
#      Account 1477: 'Yes'
#      Account 1839: 'Yes'
#      Account 1385: 'Yes'
#      Account 5485: 'Yes'
#      Account 1585: 'Yes'
#      Account 1094: 'Yes'
#      Account 6021: 'Yes'
#      Account 1789: 'Yes'
#      Account 911: 'Yes'
#      Account 1620: 'Yes'
#      Account 1841: 'Yes'
#      Account 4859: 'Yes'
#      Account 6749: 'Yes'
#      Account 1112: 'Yes'
#      Account 1824: 'Yes'
#      Account 1957: 'Yes'
#      Account 1430: 'Yes'
#      Account 1386: 'Yes'
#      Account 1587: 'Yes'
#      Account 1798: 'Yes'
#      Account 4884: 'Yes'
#      Account 1852: 'Yes'
#      Account 1851: 'Yes'
#      Account 1730: 'Yes'
#      Account 6627: 'Yes'
#      Account 1030: 'Yes'
#      Account 4892: 'Yes'
#      Account 1278: 'Yes'
#      Account 1231: 'Yes'
#      Account 5557: 'Yes'
#      Account 1324: 'Yes'
#      Account 6044: 'Yes'
#      Account 5011: 'Yes'
#      Account 1460: 'Yes'
#      Account 1511: 'Yes'
#      Account 1063: 'Yes'
#      Account 1753: 'Yes'
#      Account 1136: 'Yes'
#      Account 987: 'Yes'
#      Account 1842: 'Yes'
#      Account 967: 'Yes'
#      Account 5186: 'Yes'
#      Account 1546: 'Yes'
#      Account 1339: 'Yes'
#      Account 4945: 'Yes'
#      Account 3826: 'Yes'
#      Account 1002: 'Yes'
#      Account 5559: 'Yes'
#      Account 895: 'Yes'
#      Account 1169: 'Yes'
#      Account 1853: 'Yes'
#      Account 1590: 'Yes'
#      Account 1129: 'Yes'
#      Account 1820: 'Yes'
#      Account 1746: 'Yes'
#
# 🔍 Analyzing: V-Communications Team - website, newsletter, blog, messaging, graphic design
#   ✅ Found - ID: 78, Type: Unknown
#   📊 133 accounts have non-blank values
#   📝 Sample values:
#      Account 5602: 'Yes'
#      Account 4828: 'Yes'
#      Account 4833: 'Yes'
#      Account 4887: 'Yes'
#      Account 5217: 'Yes'
#      Account 6852: 'Yes'
#      Account 2045: 'Yes'
#      Account 4912: 'Yes'
#      Account 5247: 'Yes'
#      Account 1609: 'Yes'
#      Account 1726: 'Yes'
#      Account 3861: 'Yes'
#      Account 6532: 'Yes'
#      Account 3871: 'Yes'
#      Account 2131: 'Yes'
#      Account 2087: 'Yes'
#      Account 1473: 'Yes'
#      Account 5457: 'Yes'
#      Account 2108: 'Yes'
#      Account 5681: 'Yes'
#      Account 4757: 'Yes'
#      Account 5023: 'Yes'
#      Account 3852: 'Yes'
#      Account 5768: 'Yes'
#      Account 2088: 'Yes'
#      Account 6601: 'Yes'
#      Account 956: 'Yes'
#      Account 4665: 'Yes'
#      Account 5458: 'Yes'
#      Account 2096: 'Yes'
#      Account 1138: 'Yes'
#      Account 5680: 'Yes'
#      Account 6724: 'Yes'
#      Account 4707: 'Yes'
#      Account 4700: 'Yes'
#      Account 4905: 'Yes'
#      Account 5487: 'Yes'
#      Account 3862: 'Yes'
#      Account 6198: 'Yes'
#      Account 5440: 'Yes'
#      Account 5599: 'Yes'
#      Account 3867: 'Yes'
#      Account 6320: 'Yes'
#      Account 6203: 'Yes'
#      Account 6086: 'Yes'
#      Account 1361: 'Yes'
#      Account 1766: 'Yes'
#      Account 1534: 'Yes'
#      Account 5505: 'Yes'
#      Account 5925: 'Yes'
#      Account 2041: 'Yes'
#      Account 5918: 'Yes'
#      Account 4418: 'Yes'
#      Account 1794: 'Yes'
#      Account 3473: 'Yes'
#      Account 5474: 'Yes'
#      Account 1077: 'Yes'
#      Account 5973: 'Yes'
#      Account 1960: 'Yes'
#      Account 1866: 'Yes'
#      Account 5960: 'Yes'
#      Account 1246: 'Yes'
#      Account 1156: 'Yes'
#      Account 6603: 'Yes'
#      Account 889: 'Yes'
#      Account 5654: 'Yes'
#      Account 6224: 'Yes'
#      Account 897: 'Yes'
#      Account 1045: 'Yes'
#      Account 6649: 'Yes'
#      Account 5657: 'Yes'
#      Account 2400: 'Yes'
#      Account 2224: 'Yes'
#      Account 6021: 'Yes'
#      Account 1426: 'Yes'
#      Account 1058: 'Yes'
#      Account 5214: 'Yes'
#      Account 1492: 'Yes'
#      Account 1021: 'Yes'
#      Account 6066: 'Yes'
#      Account 4859: 'Yes'
#      Account 1957: 'Yes'
#      Account 4773: 'Yes'
#      Account 3875: 'Yes'
#      Account 1798: 'Yes'
#      Account 877: 'Yes'
#      Account 6041: 'Yes'
#      Account 5965: 'Yes'
#      Account 1963: 'Yes'
#      Account 1343: 'Yes'
#      Account 3310: 'Yes'
#      Account 1646: 'Yes'
#      Account 6477: 'Yes'
#      Account 1455: 'Yes'
#      Account 882: 'Yes'
#      Account 5787: 'Yes'
#      Account 6443: 'Yes'
#      Account 6627: 'Yes'
#      Account 3798: 'Yes'
#      Account 900: 'Yes'
#      Account 994: 'Yes'
#      Account 4803: 'Yes'
#      Account 4892: 'Yes'
#      Account 1231: 'Yes'
#      Account 2111: 'Yes'
#      Account 1787: 'Yes'
#      Account 5129: 'Yes'
#      Account 5854: 'Yes'
#      Account 5436: 'Yes'
#      Account 5444: 'Yes'
#      Account 5011: 'Yes'
#      Account 1131: 'Yes'
#      Account 967: 'Yes'
#      Account 999: 'Yes'
#      Account 5465: 'Yes'
#      Account 3858: 'Yes'
#      Account 1194: 'Yes'
#      Account 2094: 'Yes'
#      Account 1741: 'Yes'
#      Account 1803: 'Yes'
#      Account 5818: 'Yes'
#      Account 2452: 'Yes'
#      Account 4721: 'Yes'
#      Account 6655: 'Yes'
#      Account 3902: 'Yes'
#      Account 4722: 'Yes'
#      Account 5014: 'Yes'
#      Account 5559: 'Yes'
#      Account 3796: 'Yes'
#      Account 1456: 'Yes'
#      Account 5419: 'Yes'
#      Account 1457: 'Yes'
#      Account 2046: 'Yes'
#
# 🔍 Analyzing: V-Data Entry
# /Users/mdassow/development/Neon_CRM_SDK/src/neon_crm/fuzzy_search.py:237: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = token1.similarity(token2)
# 2025-10-04 15:28:15 - neon_crm.resource.customFields - INFO - Custom field 'V-Data Entry' not found in category 'Account'. Did you mean: V-Data Entry , V-Date Contacted, V-Tech Team Interests? Or perhaps you were looking for: V-Volunteer Form Submitted Date, If bringing, indicate the dish you will share.?
#   ❌ Field not found
#
# 📊 MIGRATION ANALYSIS SUMMARY
# ===================================
# ✅ V-Annual Fundraising Event Committee: 52 records
# ✅ V-Canvassing: 218 records
# ✅ V-Coffee Klatch Interest: 113 records
# ✅ V-Communications Team - website, newsletter, blog, messaging, graphic design: 133 records
# ❌ V-Data Entry: Field not found
#
# 🎯 Analysis Results:
#    Total fields analyzed: 5
#    Fields found: 4
#    Fields with data: 4
#    Total records across all fields: 516
#
# 💡 Migration Recommendations:
#    • 4 fields contain data and should be included in migration
#    • Consider data validation and cleanup for fields with many records
#    • Test migration process with a subset of accounts first
#   ✅ Found - ID: 119, Type: Unknown
#   ❌ Error analyzing field: Authentication required to access accounts
#
# 🔍 Analyzing: V-Communications Team - website, newsletter, blog, messaging, graphic design
#   ✅ Found - ID: 78, Type: Unknown
#   ❌ Error analyzing field: Authentication required to access accounts
#
# 🔍 Analyzing: V-Data Entry
# /Users/mdassow/development/Neon_CRM_SDK/src/neon_crm/fuzzy_search.py:237: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = token1.similarity(token2)
# 2025-10-03 10:03:16 - neon_crm.resource.customFields - INFO - Custom field 'V-Data Entry' not found in category 'Account'. Did you mean: V-Data Entry , V-Date Contacted, V-Tech Team Interests? Or perhaps you were looking for: V-Volunteer Form Submitted Date, If bringing, indicate the dish you will share.?
#   ❌ Field not found
#
# 📊 MIGRATION ANALYSIS SUMMARY
# ===================================
# ⚠️  V-Annual Fundraising Event Committee: Error occurred
# ⚠️  V-Canvassing: Error occurred
# ⚠️  V-Coffee Klatch Interest: Error occurred
# ⚠️  V-Communications Team - website, newsletter, blog, messaging, graphic design: Error occurred
# ❌ V-Data Entry: Field not found
#
# 🎯 Analysis Results:
#    Total fields analyzed: 5
#    Fields found: 0
#    Fields with data: 0
#    Total records across all fields: 0

# %% [markdown]
# ## Example 7: Custom Field Data Types and Validation
#
# Understanding the different types of custom fields and their characteristics.

# %%
def analyze_custom_field_types():
    """Analyze the types and characteristics of custom fields."""
    print("🔍 Custom Field Types Analysis")
    print("=" * 35)

    if not custom_fields:
        print("❌ No custom fields available for analysis")
        return

    # Group fields by type
    field_types = {}

    for field in custom_fields:
        field_type = field.get("dataType", "Unknown")
        if field_type not in field_types:
            field_types[field_type] = []
        field_types[field_type].append(field)

    print(f"Found {len(field_types)} different field types:")
    print()

    for field_type, fields in field_types.items():
        print(f"📋 {field_type} Fields ({len(fields)} total):")

        # Show first few examples
        for i, field in enumerate(fields[:3], 1):
            field_id = field.get("id")
            field_name = field.get("name", "Unknown")

            print(f"   {i}. ID {field_id}: '{field_name}'")

            # Show options if available (for dropdown/checkbox fields)
            options = field.get("options", [])
            if options:
                option_preview = ", ".join(options[:3])
                if len(options) > 3:
                    option_preview += f"... (+{len(options) - 3} more)"
                print(f"      Options: {option_preview}")

        if len(fields) > 3:
            print(f"   ... and {len(fields) - 3} more {field_type} fields")
        print()

    # Field type explanations
    print("💡 Field Type Guide:")
    field_type_info = {
        "text": "Free-form text input",
        "textarea": "Multi-line text input",
        "dropdown": "Single selection from predefined options",
        "checkbox": "Multiple selections from predefined options",
        "date": "Date values",
        "number": "Numeric values",
        "currency": "Monetary values",
        "boolean": "Yes/No or True/False values",
    }

    for ftype in field_types.keys():
        if ftype is None:
            print(f'ftype is None')
            continue
        description = field_type_info.get(ftype.lower(), "Custom field type")
        print(f"   • {ftype}: {description}")


# Run the field types analysis
print("\n🔍 Field Types Analysis")
print("=" * 25)
analyze_custom_field_types()
# Out:
# 🔍 Field Types Analysis
# =========================
# 🔍 Custom Field Types Analysis
# ===================================
# Found 3 different field types:
#
# 📋 Text Fields (2 total):
#    1. ID 111: 'DPW ID'
#    2. ID 165: 'V-Volunteer How did you hear about us'
#
# 📋 None Fields (47 total):
#    1. ID 144: 'If bringing, indicate the dish you will share.'
#    2. ID 101: 'Occupation'
#    3. ID 113: 'V-Annual Fundraising Event Committee'
#    ... and 44 more None fields
#
# 📋 Date Fields (2 total):
#    1. ID 77: 'V-Date Contacted'
#    2. ID 154: 'V-Volunteer Form Submitted Date'
#
# 💡 Field Type Guide:
#    • Text: Free-form text input
# ftype is None
#    • Date: Date values

# %% [markdown]
# ## Main Demonstration Function
#
# Run all custom field examples in sequence:

# %%
def main():
    """Run all custom field examples."""
    print("🎯 Neon CRM SDK - Custom Fields Examples")
    print("=" * 60)

    try:
        # Check if we have any custom fields to work with
        if not custom_fields:
            print("❌ No custom fields found. This could mean:")
            print("   • Your organization hasn't set up custom fields yet")
            print("   • You don't have permission to view custom fields")
            print("   • There was an error connecting to the API")
            print("\n💡 To use these examples:")
            print("   1. Set up custom fields in your Neon CRM admin panel")
            print("   2. Ensure your API key has appropriate permissions")
            print("   3. Check your organization ID and API key")
            return

        print(f"\n✅ Found {len(custom_fields)} custom fields to work with")
        print("\nRunning comprehensive custom fields examples...")

        # All examples have already been run above in their individual cells
        # This is a summary

        print("\n🎉 Custom Fields Examples Summary:")
        print("=" * 40)
        print("✅ Listed all available custom fields")
        print("✅ Demonstrated field lookup by name")
        print("✅ Showed searching by custom field values")
        print("✅ Performed multi-field searches")
        print("✅ Analyzed field types and characteristics")
        print("✅ Provided migration analysis example")

        print("\n📚 Key Learnings:")
        print("   • Custom fields extend CRM functionality")
        print("   • Use field IDs (integers) in search requests")
        print("   • Field names are used as keys in search results")
        print("   • Multiple operators available: NOT_BLANK, CONTAIN, EQUAL, etc.")
        print("   • Different field types support different operations")

        print("\n🚀 Next Steps:")
        print("   • Try creating accounts with custom field data")
        print("   • Explore updating custom field values")
        print("   • Build reports based on custom field data")
        print("   • Set up automated workflows using custom fields")

    except Exception as e:
        print(f"❌ Error running examples: {e}")
        print("💡 Please check:")
        print("   • Your network connection")
        print("   • Your API credentials (NEON_ORG_ID and NEON_API_KEY)")
        print("   • Your API permissions")


# Run the main demonstration
print("\n🎯 Running Main Custom Fields Demo")
print("=" * 40)
main()
# Out:
# 🎯 Running Main Custom Fields Demo
# ========================================
# 🎯 Neon CRM SDK - Custom Fields Examples
# ============================================================
#
# ✅ Found 51 custom fields to work with
#
# Running comprehensive custom fields examples...
#
# 🎉 Custom Fields Examples Summary:
# ========================================
# ✅ Listed all available custom fields
# ✅ Demonstrated field lookup by name
# ✅ Showed searching by custom field values
# ✅ Performed multi-field searches
# ✅ Analyzed field types and characteristics
# ✅ Provided migration analysis example
#
# 📚 Key Learnings:
#    • Custom fields extend CRM functionality
#    • Use field IDs (integers) in search requests
#    • Field names are used as keys in search results
#    • Multiple operators available: NOT_BLANK, CONTAIN, EQUAL, etc.
#    • Different field types support different operations
#
# 🚀 Next Steps:
#    • Try creating accounts with custom field data
#    • Explore updating custom field values
#    • Build reports based on custom field data
#    • Set up automated workflows using custom fields

# %% [markdown]
# ## Cleanup
#
# Don't forget to close the client connection when you're done:

# %%
# Close the client connection
client.close()
print("✅ Client connection closed.")
# Out:
# ✅ Client connection closed.

# %% [markdown]
# ## Summary and Best Practices
#
# ### What You Learned
#
# This notebook demonstrated comprehensive custom field operations:
#
# 1. **Field Discovery**: How to list and explore available custom fields
# 2. **Field Lookup**: Finding fields by name with error handling
# 3. **Basic Search**: Finding accounts with non-blank custom field values
# 4. **Value Search**: Searching for specific values in custom fields
# 5. **Multi-Field Search**: Using multiple custom fields in a single query
# 6. **Migration Analysis**: Analyzing field usage for data migration
# 7. **Field Types**: Understanding different custom field types
#
# ### Best Practices
#
# #### Search Operations
# - Use **field IDs (integers)** in search requests, not field names
# - Field **names are used as keys** in search results
# - Always handle the case where fields might not exist
# - Use appropriate operators: `NOT_BLANK`, `CONTAIN`, `EQUAL`, etc.
#
# #### Performance
# - Use pagination for large result sets
# - Limit output fields to only what you need
# - Consider caching field metadata for frequently used fields
#
# #### Error Handling
# - Always check if custom fields exist before using them
# - Handle API errors gracefully
# - Provide meaningful error messages to users
#
# #### Field Types
# - **Text/Textarea**: Use `CONTAIN` for partial matches, `EQUAL` for exact matches
# - **Dropdown/Checkbox**: Use `EQUAL` with exact option values
# - **Date**: Use date-specific operators and proper formatting
# - **Number/Currency**: Use numeric operators and appropriate data types
#
# ### Common Use Cases
#
# - **Volunteer Management**: Track skills, interests, and availability
# - **Donor Segmentation**: Categorize donors by giving capacity or interests
# - **Event Management**: Track event preferences and participation history
# - **Communication Preferences**: Manage how contacts want to be reached
# - **Legacy System Integration**: Store IDs from other systems
#
# ### Next Steps
#
# Now that you understand custom fields, explore:
#
# - **Account Creation with Custom Fields**: Set custom field values when creating accounts
# - **Bulk Updates**: Update custom fields for multiple accounts
# - **Reporting**: Build reports based on custom field data
# - **Advanced Search**: Combine custom fields with standard fields in complex queries
#
# Custom fields are one of the most powerful features of the Neon CRM SDK - use them to make your CRM work exactly the way your organization needs! 🎯
